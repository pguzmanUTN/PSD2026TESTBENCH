# %% [markdown]
# # Tarea Semanal 1
# ## Autor: Pedro Guzman

# %% [markdown]
# ### Consigna
#
# En este primer trabajo comenzaremos por diseñar un generador de señales que utilizaremos en las primeras simulaciones que hagamos. La primer tarea consistirá en programar una función que genere señales senoidales y que permita parametrizar:
#
# * la amplitud máxima de la senoidal (volts)
# * su valor medio (volts)
# * la frecuencia (Hz)
# * la fase (radianes)
# * la cantidad de muestras digitalizada por el ADC (# muestras)
# * la frecuencia de muestreo del ADC.
# es decir que la función que uds armen debería admitir se llamada de la siguiente manera
#
# tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs)
#
# Recuerden que tanto xx como tt deben ser vectores de Nx1. Puede resultarte útil el módulo de visualización matplotlib.pyplot donde encontrarán todas las funciones de visualización estilo Matlab. Para usarlo:
#
# import matplotlib.pyplot as plt
# plt.plot(tt, xx)
# Entrega
# Recuerden que solo tienen que entregar una URL a su notebook. Con esa URL ya tendré acceso a su repositorio y todo lo que usaron.
#
# https://nbviewer.jupyter.org/github/marianux/PDS/blob/main/preparacion.ipynb
#
# ### Bonus
# * 💎 Ser el primero en subir un enlace a tu notebook en esta tarea
# * 🤯 Implementar alguna otra señal propia de un generador de señales.
#
# ### Ayudas
#
# * La función numpy.sin seguro te va a servir.
# * No hace falta usar ningún lazo de control for, while, etc.
# *Podés consultar en el chat cualquier duda o problema que vayas encontrando. Buena suerte!

# %% [markdown]
# ### Solucion Propuesta

# %%
#Imports
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sp

# %%
#Funcion del generador de se;ales
def  mi_funcion ( vmax = 1, dc = 0, ff = 1, ph = 0, nn = 100, fs = 50, type_s = 'sine', duty = 0.5, vmed=5e-3, vsigma=0.5e-3) :
    
    tt = np.arange(start = 0, step = 1/fs, stop = nn/fs)
    if   type_s == 'sine' :
        xx = vmax*np.sin(2*np.pi*ff*tt+ph)+dc
    elif type_s == 'sawtooth' :
        xx = vmax*sp.sawtooth(2*np.pi*ff*tt+ph)+dc
    elif type_s == 'triangle' :
        xx = vmax*sp.sawtooth(2*np.pi*ff*tt+ph,width = 0.5)+dc
    elif type_s == 'invsawtooth' :
        xx = vmax*sp.sawtooth(2*np.pi*ff*tt+ph, width = 0)+dc
    elif type_s == 'square' :
        xx = vmax*sp.square(2*np.pi*ff*tt+ph, duty = duty)+dc
    elif type_s == 'noise' :
        xx = np.random.normal(vmed, vsigma, len(tt))+dc
    else :
        print("Tipo de funcion no existente o incorrecta")
    
    return tt, xx

# %%
#Parametros del muestreo
N    = 1000 #Muestras
fs   = N #Resolucion espectral normalizada
#Parametros de la Senal
ff   = 10 # Hz
vmax = 5 #Volt
dc   = 1 #Volt
px   = np.pi/2 #rads
type_s = 'sine'
duty = 0.75 #Solo para senal cuadrada

# %%
tt, xx = mi_funcion( vmax = vmax, dc = dc, ff = ff, ph= px, nn = N, fs = fs, type_s = type_s)
plt.figure(figsize=(13, 4)) 
plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_funcion( vmax = vmax, dc = dc, ff = ff, ph= px, nn = N, fs = fs, type_s = 'square', duty = duty)
plt.figure(figsize=(13, 4)) 
plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_funcion( vmax = vmax, dc = dc, ff = ff, ph= px, nn = N, fs = fs, type_s = 'sawtooth')
plt.figure(figsize=(13, 4)) 
plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_funcion( vmax = vmax, dc = dc, ff = ff, ph= px, nn = N, fs = fs, type_s = 'invsawtooth')
plt.figure(figsize=(13, 4)) 
plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_funcion( vmax = vmax, dc = dc, ff = ff, ph= px, nn = N, fs = fs, type_s = 'triangle')
plt.figure(figsize=(13, 4)) 
plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %% [markdown]
# #### Experimiento Propusto

# %%
tt, xx = mi_funcion( vmax = vmax, dc = 0, ff = 500, ph= 0, nn = 1000, fs = 1000, type_s = 'sine')
plt.figure(figsize=(13, 4)) 
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %% [markdown]
# Como no le puse fase a la senal, estoy muestreand casi siemre el mismo punto, el 0 de la senal senoidal,o el mismo punto corrido un poco. El eje Y esta por 10^-12

# %%
tt, xx = mi_funcion( vmax = vmax, dc = 0, ff = 999, ph= 0, nn = 1000, fs = 1000, type_s = 'sine')
plt.figure(figsize=(13, 4)) 
#plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %% [markdown]
# Estoy submestreando, y estoy muy cerca de la frecuencia de nyquist, tengo los espectros solapados, entonces no hay forma que recupere la senal de informacion original, se me creo una copia de mi espectro original sobre fs y multiplos de fs, y como la diferencia entre fs y la frecuencia de la senal ff es 1000 - 999 se me creo una senal de 1Hz, especificamente la delta de frecuencia de la senal senoidal original con fase de pi quedo parada en la frecuencia de 1Hz

# %%
tt, xx = mi_funcion( vmax = vmax, dc = 0, ff = 1001, ph= 0, nn = 1000, fs = 1000, type_s = 'sine')
plt.figure(figsize=(13, 4)) 
#plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %% [markdown]
# Idem caso anterior pero la delta que queda en la frecuencia de 1Hz es la de la senal original con fase 0

# %%
tt, xx = mi_funcion( vmax = vmax, dc = 0, ff = 2001, ph= 0, nn = 1000, fs = 1000, type_s = 'sine')
plt.figure(figsize=(13, 4)) 
#plt.xlim([0,5/ff]) #Para que me muestre 5 ciclos
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %% [markdown]
# Idem caso anterior pero es la frecuencia 2fs que tiene el espectro copiado y que deja la frecuencia de la senal original en esa porcion del espectro.

# %% [markdown]
# #### Generador de Ruido

# %%
vmed = 5e-3
vsigma = 0.1e-3
tt, xx = mi_funcion( vmed = vmed, vsigma = vsigma, nn = 1000000, fs = 1000, type_s = 'noise')
plt.figure(figsize=(13, 4)) 
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")

plt.figure(figsize=(13, 4)) 
count, bins, _ = plt.hist(xx, 100, density=True)
plt.plot(bins, 1/(vsigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - vmed)**2 / (2 * vsigma**2) ),
         linewidth=2, color='r')

print(abs(vmed - np.mean(xx)))
abs(vsigma - np.std(xx, ddof=1))
# Out:
# 6.441229138346577e-08
# np.float64(9.509284047076272e-08)

# %% [markdown]
# #### Generador de Senoidal con ruido

# %%
#Funcion del generador de se;ales
def  mi_generador_ruidoso ( Psine = 1,R = 1 ,SNRdB=10, ff = 1, ph = 0, nn = 100, fs = 50) :
    vmax=np.sqrt(Psine*2*R)
    Pnoise=Psine/(10**(SNRdB/10))
    vsigma=np.sqrt(Pnoise*R)
    tt = np.arange(start = 0, step = 1/fs, stop = nn/fs)
    _, xx_sine = mi_funcion( vmax = vmax, dc = 0, ff = ff, ph= ph, nn = nn, fs = fs, type_s = 'sine')
    _ ,xx_noise = mi_funcion( vmed = 0, vsigma = vsigma, nn = nn, fs = fs, type_s = 'noise')
    xx= xx_sine + xx_noise
    SNR_real = 10 * np.log10(Psine / np.var(xx_noise))
    print(f"SNR real: {SNR_real:.9f} dB")
    return tt, xx

# %%
tt, xx = mi_generador_ruidoso( Psine = 1,R = 1 ,SNRdB=10, ff = 1, ph = 0, nn = 500, fs = 50)
plt.figure(figsize=(13, 4)) 
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# SNR real: 10.042707020 dB
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_generador_ruidoso( Psine = 1,R = 1 ,SNRdB=20, ff = 1, ph = 0, nn = 500, fs = 50)
plt.figure(figsize=(13, 4)) 
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# SNR real: 19.810843119 dB
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_generador_ruidoso( Psine = 1,R = 1 ,SNRdB=30, ff = 1, ph = 0, nn = 500, fs = 50)
plt.figure(figsize=(13, 4)) 
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# SNR real: 29.975105221 dB
# Text(0.5, 0, 'Tiempo [s]')

# %%
tt, xx = mi_generador_ruidoso( Psine = 1,R = 1 ,SNRdB=40, ff = 1, ph = 0, nn = 500, fs = 50)
plt.figure(figsize=(13, 4)) 
plt.plot(tt, xx, marker = 'X', color = 'r', linestyle = '-')
plt.grid()
plt.title("Salida Generador de Senales")
plt.ylabel("Amplitud [V]")
plt.xlabel("Tiempo [s]")
# Out:
# SNR real: 40.167585037 dB
# Text(0.5, 0, 'Tiempo [s]')
